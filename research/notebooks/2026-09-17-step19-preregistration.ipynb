# %% [markdown]
# # 2026-09-17 — Step 19 Preregistration
#
# **Research program:** Interactive Digital Humans / Real-Time 4D Human Intelligence
# **Paper 1:** Anatomical locality in learned animatable-human deformation
# **Status:** Step 18 frozen at 18D1. Step 19 method implementation has **not** started.
#
# ## Frozen Step 18 conclusions
#
# - Branch-mediated causality: `SUPPORTED_FOR_ALL_THREE_TESTED_JOINTS`
# - Learned-vs-K6 amplification: `JOINT_DEPENDENT_NOT_UNIVERSAL`
# - Shoulder preregistered generalization: `FAIL_UNCHANGED`
# - Exploratory dominant mechanism: `DESCENDANT_SUPPORT_TOPOLOGY_AND_PER_ROW_MAGNITUDE`
# - Within-branch composition: `SMALL_EFFECT_ON_DEFINED_OVERLAP`
# - Kinematic depth: `NOT_ESTABLISHED_AS_CAUSAL`
#
# ## Today's rule
#
# Do **not** implement a corrective method yet. First freeze the Step 19 preregistration.

# %% [markdown]
# ## Step 19 working question
#
# > **Can anatomical locality be enforced without sacrificing reconstruction quality?**
#
# Working hypothesis to review before freezing:
#
# > A mechanism-aware anatomical-locality constraint on learned descendant-branch support can suppress anatomically nonlocal deformation while preserving reconstruction and novel-pose quality.
#
# This is **not frozen yet**.

# %%
# STEP 19A — CREATE TODAY'S PRIVATE PREREGISTRATION DRAFT
# Run this single cell first. It does not implement or train any method.

from google.colab import drive
from pathlib import Path

drive.mount("/content/drive")

root = Path("/content/drive/MyDrive/interactive-digital-humans")
private_dir = root / "private_research"
private_dir.mkdir(parents=True, exist_ok=True)

out = private_dir / "2026-09-17_step19_preregistration_draft.md"

template = '''# Step 19 Preregistration Draft
Date: 2026-09-17
Status: DRAFT — NOT FROZEN

## 1. Research question
Can anatomical locality be enforced without sacrificing reconstruction quality?

## 2. Corrective-method hypothesis
[TBD — freeze before implementation]

## 3. Quantity to regularize / constrain
[TBD]

## 4. Formal locality definition
[TBD]

## 5. Primary locality metric
[TBD]

## 6. Reconstruction-quality metrics
[TBD]

## 7. Baselines
[TBD]

## 8. Success thresholds
[TBD]

## 9. Held-out / generalization protocol
[TBD]

## 10. Ablation plan
[TBD]

## 11. Failure acceptance rule
Negative results remain valid. Do not retune thresholds after observing outcomes.

## 12. Scope boundary
Current diagnosis evidence is HUGS / NeuMan / 3 pretrained checkpoints / one left-arm chain.
Cross-method or broad learned-human claims require new evidence.

## 13. Public-disclosure rule
Do not publish novel loss / architecture / training details to the public GitHub before advisor/lab/IP alignment.
'''

out.write_text(template, encoding="utf-8")

print("=" * 88)
print("STEP 19A — PRIVATE PREREGISTRATION DRAFT INITIALIZED")
print("=" * 88)
print("saved:", out)
print()
print("NO METHOD IMPLEMENTATION HAS STARTED.")
print("Send me this full output before we continue.")
