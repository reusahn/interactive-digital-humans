# %% [markdown]
# # Daily Research Notebook — 2026-09-16
#
# Current research state: Step 17C0 frozen two-joint benchmark complete.
#
# Today starts from a clean Colab runtime. Run only the next instructed cell, send the full output back, and wait for the next checkpoint.
#
# Do not rerun the historical Experiment 01/02 notebooks from top to bottom.

# %%
# STEP 0 — Daily startup: mount Drive and verify frozen research artifacts
from google.colab import drive
drive.mount('/content/drive')

from pathlib import Path

ROOT = Path('/content/drive/MyDrive/interactive-digital-humans')

required = [
    ROOT / 'experiments/08-second-joint-generalization/17A2_frozen_canonical_anatomy_masks.npz',
    ROOT / 'experiments/04-k6-support-mapping/13E_learned_lbs_weights.npz',
    ROOT / 'experiments/04-k6-support-mapping/13A_k6_effective_mapping.npz',
    ROOT / 'experiments/07-cross-sequence-replication/16C1_parkinglot_learned_lbs.npz',
    ROOT / 'experiments/07-cross-sequence-replication/16C2_parkinglot_k6_effective_mapping.npz',
    ROOT / 'experiments/07-cross-sequence-replication/16D2_jogging_learned_lbs.npz',
    ROOT / 'experiments/07-cross-sequence-replication/16D3_jogging_k6_effective_mapping.npz',
]

print('Drive mounted:', ROOT.exists())
print('Research root:', ROOT)
print('\nRequired artifacts:')
all_ok = True
for p in required:
    ok = p.exists()
    all_ok &= ok
    print(f'{ok!s:5s}  {p}')

print('\nDAILY STARTUP PASS:', all_ok)
print('Send the FULL output back before running the next research step.')
